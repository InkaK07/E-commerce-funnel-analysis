# %% [markdown]
# # E-commerce Funnel Analysis
#
# Objective: Clean data, explore and arrive at e-commerce insights.
#
# Events are:
# View -> Cart
# View -> Purcase
# Cart -> Purchase
#
# Conversion = Purchase
#
# Questions I will answer with this analysis:
#
# 1. What is the event distribution over time (6 months)?
# 1. Where is the biggest drop-off in the funnel? At which stage (over a time period of 6 months).
# 3. What is the total conversion rate (over the period of 6 months).
# 4. What is the median time to purchase?
# 5. What is the median price of a purchase?
# 6. Distribution of purchases by hour.
# 7. What are the highest-selling categories?
#
#
# But first lets explore the datasets

# %%
import pandas as pd 
import numpy as np
import seaborn as sns

Nov= pd. read_csv("2019-Nov.csv")
Oct= pd. read_csv("2019-Oct.csv")

# %%
Nov.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67501979 entries, 0 to 67501978
# Data columns (total 9 columns):
#  #   Column         Dtype
# ---  ------         -----
#  0   event_time     object
#  1   event_type     object
#  2   product_id     int64
#  3   category_id    int64
#  4   category_code  object
#  5   brand          object
#  6   price          float64
#  7   user_id        int64
#  8   user_session   object
# dtypes: float64(1), int64(3), object(5)
# memory usage: 4.5+ GB

# %%
Nov.columns
# Out:
# Index(['event_time', 'event_type', 'product_id', 'category_id',
#        'category_code', 'brand', 'price', 'user_id', 'user_session'],
#       dtype='object')

# %%
Oct.columns
# Out:
# Index(['event_time', 'event_type', 'product_id', 'category_id',
#        'category_code', 'brand', 'price', 'user_id', 'user_session'],
#       dtype='object')

# %%
Oct.head(10)
# Out:
#                 event_time event_type  product_id          category_id  \
# 0  2019-10-01 00:00:00 UTC       view    44600062  2103807459595387724
# 1  2019-10-01 00:00:00 UTC       view     3900821  2053013552326770905
# 2  2019-10-01 00:00:01 UTC       view    17200506  2053013559792632471
# 3  2019-10-01 00:00:01 UTC       view     1307067  2053013558920217191
# 4  2019-10-01 00:00:04 UTC       view     1004237  2053013555631882655
# 5  2019-10-01 00:00:05 UTC       view     1480613  2053013561092866779
# 6  2019-10-01 00:00:08 UTC       view    17300353  2053013553853497655
# 7  2019-10-01 00:00:08 UTC       view    31500053  2053013558031024687
# 8  2019-10-01 00:00:10 UTC       view    28719074  2053013565480109009
# 9  2019-10-01 00:00:11 UTC       view     1004545  2053013555631882655
#
#                          category_code     brand    price    user_id  \
# 0                                  NaN  shiseido    35.79  541312140
# ...

# %%
Nov.head(10)
# Out:
#                 event_time event_type  product_id          category_id  \
# 0  2019-11-01 00:00:00 UTC       view     1003461  2053013555631882655
# 1  2019-11-01 00:00:00 UTC       view     5000088  2053013566100866035
# 2  2019-11-01 00:00:01 UTC       view    17302664  2053013553853497655
# 3  2019-11-01 00:00:01 UTC       view     3601530  2053013563810775923
# 4  2019-11-01 00:00:01 UTC       view     1004775  2053013555631882655
# 5  2019-11-01 00:00:01 UTC       view     1306894  2053013558920217191
# 6  2019-11-01 00:00:01 UTC       view     1306421  2053013558920217191
# 7  2019-11-01 00:00:02 UTC       view    15900065  2053013558190408249
# 8  2019-11-01 00:00:02 UTC       view    12708937  2053013553559896355
# 9  2019-11-01 00:00:02 UTC       view     1004258  2053013555631882655
#
#                category_code     brand   price    user_id  \
# 0     electronics.smartphone    xiaomi  489.07  520088904
# 1  appliances.sewing_machine    janome  293.65  530496790
# ...

# %%
Nov.tail(10)
# Out:
#                        event_time event_type  product_id          category_id  \
# 67501969  2019-11-30 23:59:55 UTC       view     1500447  2053013552955916539
# 67501970  2019-11-30 23:59:55 UTC       view    16800304  2053013558316237377
# 67501971  2019-11-30 23:59:57 UTC       view     8800713  2053013555573162395
# 67501972  2019-11-30 23:59:57 UTC       view    12301059  2053013556311359947
# 67501973  2019-11-30 23:59:57 UTC       view    10502879  2053013553199186187
# 67501974  2019-11-30 23:59:58 UTC       view    15700137  2053013559733912211
# 67501975  2019-11-30 23:59:58 UTC       view    28719425  2053013565639492569
# 67501976  2019-11-30 23:59:59 UTC       view     1004833  2053013555631882655
# 67501977  2019-11-30 23:59:59 UTC       view     2701706  2053013563911439225
# 67501978  2019-11-30 23:59:59 UTC       view     1004233  2053013555631882655
#
#                              category_code      brand    price    user_id  \
# ...

# %%
print(Nov.shape)
print(Oct.shape)

# By now I have realized that Oct and Nov CSV files are quuite large, so I will be working with this dataset in chunks.
# Out:
# (67501979, 9)
# (42448764, 9)

# %%
Nov["event_type"].value_counts()
Oct["event_type"].value_counts()
# Out:
# event_type
# view        40779399
# cart          926516
# purchase      742849
# Name: count, dtype: int64

# %%
Nov["user_id"].nunique()
# Out:
# 3696117

# %%
Oct["user_id"].nunique()
# Out:
# 3022290

# %%
Nov["category_id"].nunique()
# Out:
# 684

# %%
Oct["category_id"].nunique()
# Out:
# 624

# %%
Nov["category_code"].nunique()
Nov["category_code"].value_counts()
# Out:
# category_code
# electronics.smartphone          16375000
# electronics.video.tv             2208046
# computers.notebook               2180554
# electronics.clocks               2086966
# apparel.shoes                    1886890
#                                   ...
# apparel.shorts                       652
# construction.tools.screw             184
# appliances.kitchen.fryer             108
# country_yard.furniture.bench           2
# apparel.jacket                         1
# Name: count, Length: 129, dtype: int64

# %%
Oct["category_code"].nunique()
# Out:
# 126

# %%
del Oct, Nov
